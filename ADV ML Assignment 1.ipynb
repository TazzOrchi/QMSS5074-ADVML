# %% [markdown]
# # Assignment #1: Write up a report on U.N. World Happiness Data

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade
# Out:
# Collecting aimodelshare
#   Using cached aimodelshare-0.0.178-py3-none-any.whl (966 kB)
# Collecting torch>=1.8.1
#   Using cached torch-1.13.1-cp39-cp39-win_amd64.whl (162.5 MB)
# Collecting tensorflow==2.9.2
#   Using cached tensorflow-2.9.2-cp39-cp39-win_amd64.whl (444.1 MB)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (1.13.0)
# Collecting psutil>=5.9.1
#   Using cached psutil-5.9.4-cp36-abi3-win_amd64.whl (252 kB)
# Requirement already satisfied: PyJWT>=2.4.0 in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (2.4.0)
# Collecting keras2onnx>=1.7.0
#   Using cached keras2onnx-1.7.0-py3-none-any.whl (96 kB)
# Requirement already satisfied: botocore==1.24.20 in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (1.24.20)
# Requirement already satisfied: seaborn>=0.11.2 in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (0.11.2)
# Collecting onnxruntime>=1.7.0
#   Using cached onnxruntime-1.13.1-cp39-cp39-win_amd64.whl (5.9 MB)
# Collecting onnxmltools>=1.6.1
#   Using cached onnxmltools-1.11.1-py3-none-any.whl (308 kB)
# Requirement already satisfied: onnx==1.12.0 in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (1.12.0)
# Requirement already satisfied: regex in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (2021.8.3)
# Collecting importlib-resources==5.10.0
#   Using cached importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting docker==5.0.0
#   Using cached docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: scikit-learn==0.24.2 in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (0.24.2)
# Collecting wget==3.2
#   Using cached wget-3.2-py3-none-any.whl
# Collecting astunparse==1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: skl2onnx>=1.8.0 in c:\users\tasnu\anaconda3\lib\site-packages (from aimodelshare) (1.13)
# Collecting boto3==1.21.20
#   Using cached boto3-1.21.20-py3-none-any.whl (132 kB)
# Collecting pydot==1.3.0
#   Using cached pydot-1.3.0-py2.py3-none-any.whl (18 kB)
# Collecting pathlib>=1.0.1
#   Using cached pathlib-1.0.1-py3-none-any.whl (14 kB)
# Collecting shortuuid>=1.0.8
#   Using cached shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting tf2onnx
#   Using cached tf2onnx-1.13.0-py3-none-any.whl (442 kB)
# Collecting Pympler==0.9
#   Using cached Pympler-0.9-py3-none-any.whl
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tasnu\anaconda3\lib\site-packages (from astunparse==1.6.3->aimodelshare) (0.37.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\tasnu\anaconda3\lib\site-packages (from astunparse==1.6.3->aimodelshare) (1.16.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\tasnu\anaconda3\lib\site-packages (from boto3==1.21.20->aimodelshare) (0.5.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\tasnu\anaconda3\lib\site-packages (from boto3==1.21.20->aimodelshare) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\tasnu\anaconda3\lib\site-packages (from botocore==1.24.20->aimodelshare) (1.26.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\tasnu\anaconda3\lib\site-packages (from botocore==1.24.20->aimodelshare) (2.8.2)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in c:\users\tasnu\anaconda3\lib\site-packages (from docker==5.0.0->aimodelshare) (2.26.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\tasnu\anaconda3\lib\site-packages (from docker==5.0.0->aimodelshare) (1.5.1)
# Collecting pywin32==227
#   Using cached pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\tasnu\anaconda3\lib\site-packages (from importlib-resources==5.10.0->aimodelshare) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\tasnu\anaconda3\lib\site-packages (from onnx==1.12.0->aimodelshare) (3.10.0.2)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in c:\users\tasnu\anaconda3\lib\site-packages (from onnx==1.12.0->aimodelshare) (3.19.6)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\tasnu\anaconda3\lib\site-packages (from onnx==1.12.0->aimodelshare) (1.22.4)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\tasnu\anaconda3\lib\site-packages (from pydot==1.3.0->aimodelshare) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\tasnu\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\tasnu\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tasnu\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (2.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (3.2.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: packaging in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (1.4.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (2.9.1)
# Collecting libclang>=13.0.0
#   Using cached libclang-15.0.6.1-py2.py3-none-win_amd64.whl (23.2 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (2.2.0)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: setuptools in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (58.0.4)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (0.30.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (1.12.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorflow==2.9.2->aimodelshare) (1.51.1)
# Collecting fire
#   Using cached fire-0.5.0-py2.py3-none-any.whl
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: sympy in c:\users\tasnu\anaconda3\lib\site-packages (from onnxruntime>=1.7.0->aimodelshare) (1.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tasnu\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tasnu\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tasnu\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.0.4)
# Requirement already satisfied: pandas>=0.23 in c:\users\tasnu\anaconda3\lib\site-packages (from seaborn>=0.11.2->aimodelshare) (1.3.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\tasnu\anaconda3\lib\site-packages (from seaborn>=0.11.2->aimodelshare) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tasnu\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tasnu\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tasnu\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tasnu\anaconda3\lib\site-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2021.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.16.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\tasnu\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tasnu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tasnu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tasnu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\tasnu\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\tasnu\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tasnu\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tasnu\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\tasnu\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.7.0->aimodelshare) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\tasnu\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.7.0->aimodelshare) (3.4.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\tasnu\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.2.1)
# Installing collected packages: pywin32, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, fire, coloredlogs, astunparse, wget, torch, tf2onnx, tensorflow, shortuuid, Pympler, pydot, psutil, pathlib, onnxruntime, onnxmltools, keras2onnx, importlib-resources, docker, boto3, aimodelshare
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 228
#     Uninstalling pywin32-228:
#       Successfully uninstalled pywin32-228
#   Rolling back uninstall of pywin32
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\tasnu\AppData\Local\Temp\pip-uninstall-xwfxa4ge\pythoncom.cpython-39.pyc
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\tasnu\anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\isapi
#    from C:\Users\tasnu\anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\pythoncom.py
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\tasnu\\anaconda3\\Lib\\site-packages\\pywin32_system32\\pywintypes39.dll'
# Consider using the `--user` option or check the permissions.
#    from C:\Users\tasnu\AppData\Local\Temp\pip-uninstall-9_r9ypis\pythoncom.py
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\tasnu\anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\pywin32-228-py3.9.egg-info
#    from C:\Users\tasnu\anaconda3\Lib\site-packages\~ywin32-228-py3.9.egg-info
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\tasnu\anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\win32com
#    from C:\Users\tasnu\anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\tasnu\anaconda3\lib\site-packages\win32comext
#    from C:\Users\tasnu\anaconda3\Lib\site-packages\~in32comext
